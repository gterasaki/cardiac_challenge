# %% [markdown]
# # Xgboost when using ECG signals as inputs

# %% [markdown]
# ## Load dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, TensorDataset

# %%
from sklearn.model_selection import train_test_split

# Load the data
df_ptbd_normal = pd.read_csv("../ecg_dataset/ptbdb_normal.csv", header=None)
df_ptbd_abnormal = pd.read_csv("../ecg_dataset/ptbdb_abnormal.csv", header=None)

RANDOM_STATE = 0

# Split the normal and abnormal datasets into train, validation (CV), and test sets
X_train_normal, X__normal, y_train_normal, y__normal = train_test_split(
    df_ptbd_normal.iloc[:, :-1], df_ptbd_normal.iloc[:, -1], test_size=0.20, random_state=RANDOM_STATE)
X_train_abnormal, X__abnormal, y_train_abnormal, y__abnormal = train_test_split(
    df_ptbd_abnormal.iloc[:, :-1], df_ptbd_abnormal.iloc[:, -1], test_size=0.20, random_state=RANDOM_STATE)

X_cv_normal, X_test_normal, y_cv_normal, y_test_normal = train_test_split(
    X__normal, y__normal, test_size=0.5, random_state=RANDOM_STATE)
X_cv_abnormal, X_test_abnormal, y_cv_abnormal, y_test_abnormal = train_test_split(
    X__abnormal, y__abnormal, test_size=0.5, random_state=RANDOM_STATE)


# Determine the size for undersampling (number of samples in the smaller training class)
min_train_size = min(len(X_train_normal), len(X_train_abnormal))

# Perform undersampling on the training set
X_train_normal_under = X_train_normal.sample(n=min_train_size, random_state=42)
y_train_normal_under = y_train_normal.sample(n=min_train_size, random_state=42)

X_train_abnormal_under = X_train_abnormal.sample(n=min_train_size, random_state=42)
y_train_abnormal_under = y_train_abnormal.sample(n=min_train_size, random_state=42)

# Combine the undersampled training data
X_train = pd.concat([X_train_normal_under, X_train_abnormal_under], axis=0)
y_train = pd.concat([y_train_normal_under, y_train_abnormal_under], axis=0)

# Shuffle the combined training data
X_train, y_train = X_train.sample(frac=1, random_state=42).reset_index(drop=True), y_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Combine the validation and test datasets without undersampling
X_cv = pd.concat([X_cv_normal, X_cv_abnormal], axis=0)
y_cv = pd.concat([y_cv_normal, y_cv_abnormal], axis=0)

X_test = pd.concat([X_test_normal, X_test_abnormal], axis=0)
y_test = pd.concat([y_test_normal, y_test_abnormal], axis=0)

# Print the shapes of the datasets
print("Training set shape:", X_train.shape)
print("Validation set shape:", X_cv.shape)
print("Test set shape:", X_test.shape)
print("Training labels shape:", y_train.shape)
print("Validation labels shape:", y_cv.shape)
print("Test labels shape:", y_test.shape)
# Out:
# Training set shape: (6472, 187)
# Validation set shape: (1456, 187)
# Test set shape: (1456, 187)
# Training labels shape: (6472,)
# Validation labels shape: (1456,)
# Test labels shape: (1456,)

# %% [markdown]
# # Training Model for Task 1

# %%
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from xgboost import XGBClassifier

# %%
# Initialize the XGBClassifier with regularization and early stopping
xgb_model1 = XGBClassifier(n_estimators=500, learning_rate=0.1, max_depth=4,
                          reg_alpha=0.1, reg_lambda=0.1, subsample=0.8,
                          colsample_bytree=0.8, verbosity=0, early_stopping_rounds=50, random_state=RANDOM_STATE)

# Fit the model with early stopping
xgb_model1.fit(X_train, y_train,
              eval_set=[(X_cv, y_cv)],
              verbose=False)

# # Initialize the XGBClassifier
# xgb_model = XGBClassifier(n_estimators=100, learning_rate=0.1, verbosity=0, random_state=55,early_stopping_rounds=50)

# # Fit the model with early stopping
# xgb_model.fit(X_train, y_train, 
#               eval_set=[(X_cv, y_cv)], 
#                 # This should work for the XGBoost library
#               verbose=True)  # To see the evaluation metric at each step

# Step 5: Evaluate the Model
train_accuracy = accuracy_score(y_train, xgb_model1.predict(X_train))
cv_accuracy = accuracy_score(y_cv, xgb_model1.predict(X_cv))
test_accuracy = accuracy_score(y_test, xgb_model1.predict(X_test))

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Validation Accuracy: {cv_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Training Accuracy: 1.0000
# Validation Accuracy: 0.9636
# Test Accuracy: 0.9753

# %%
import joblib

# Save the model to a file
joblib.dump(xgb_model1, 'task1_1D_xgb_model500.pkl')
# Out:
# ['task1_1D_xgb_model500.pkl']

# %%
# Step 1: Load the saved model
xgb_model1 = joblib.load('task1_1D_xgb_model500.pkl')


# Step 3: Evaluate the loaded model
train_accuracy = accuracy_score(y_train, xgb_model1.predict(X_train))
cv_accuracy = accuracy_score(y_cv, xgb_model1.predict(X_cv))
test_accuracy = accuracy_score(y_test, xgb_model1.predict(X_test))

# Step 4: Print the accuracy for each dataset
print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Validation Accuracy: {cv_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Training Accuracy: 1.0000
# Validation Accuracy: 0.9636
# Test Accuracy: 0.9753

# %%
import seaborn as sns

# XGBoost Model Evaluation on Train and Test Data
print("\nXGBOOST Evaluation\n")

# Classification Report on Test Data
print("Classification Report (Test):")
print(classification_report(y_test, xgb_model1.predict(X_test)))

# Confusion Matrix on Test Data
print("Confusion Matrix (Test):")
conf_test = confusion_matrix(y_test, xgb_model1.predict(X_test))
print(conf_test)

# Accuracy Scores
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(xgb_model1.predict(X_train), y_train):.4f}")
print(f"Metrics test:\n\tAccuracy score: {accuracy_score(xgb_model1.predict(X_test), y_test):.4f}")


# Visualization for the Test Confusion Matrix
plt.figure(figsize=(10, 7.5))
sns.heatmap(conf_test, annot=True, cmap='BrBG', fmt='g')
plt.title("Confusion Matrix - Test Set")
plt.show()
# Out:
# XGBOOST Evaluation
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.99      0.96       405
#          1.0       0.99      0.97      0.98      1051
#
#     accuracy                           0.98      1456
#    macro avg       0.96      0.98      0.97      1456
# weighted avg       0.98      0.98      0.98      1456
#
# Confusion Matrix (Test):
# [[ 399    6]
#  [  30 1021]]
# Metrics train:
# 	Accuracy score: 1.0000
# Metrics test:
# 	Accuracy score: 0.9753

# %% [markdown]
# # Xgboost when using GAF images as inputs

# %%
# Load the flattened arrays and labels from .npy files with 'task1_' prefix
X_train_flat = np.load('task1_X_train_flat.npy')
X_cv_flat = np.load('task1_X_cv_flat.npy')
X_test_flat = np.load('task1_X_test_flat.npy')
y_train = np.load('task1_y_train.npy')
y_cv = np.load('task1_y_cv.npy')
y_test = np.load('task1_y_test.npy')

print("Flattened GAF images and labels have been loaded successfully with 'task1_' prefix.")
# Out:
# Flattened GAF images and labels have been loaded successfully with 'task1_' prefix.

# %%
# Print the shapes of the datasets
print("Training set shape:", X_train.shape)
print("Validation set shape:", X_cv.shape)
print("Test set shape:", X_test.shape)
print("Training labels shape:", y_train.shape)
print("Validation labels shape:", y_cv.shape)
print("Test labels shape:", y_test.shape)

print("\n")
# Check the sizes of the loaded arrays
print("X_train_flat shape:", X_train_flat.shape)
print("X_cv_flat shape:", X_cv_flat.shape)
print("X_test_flat shape:", X_test_flat.shape)
print("y_train shape:", y_train.shape)
print("y_cv shape:", y_cv.shape)
print("y_test shape:", y_test.shape)
# Out:
# Training set shape: (6472, 187)
# Validation set shape: (1456, 187)
# Test set shape: (1456, 187)
# Training labels shape: (6472,)
# Validation labels shape: (1456,)
# Test labels shape: (1456,)
#
#
# X_train_flat shape: (6472, 50176)
# X_cv_flat shape: (1456, 50176)
# X_test_flat shape: (1456, 50176)
# y_train shape: (6472,)
# y_cv shape: (1456,)
# y_test shape: (1456,)

# %%
# Step 4: Training the XGBoost Model
xgb_model1 = XGBClassifier(n_estimators=500, learning_rate=0.1, max_depth=4,
                          reg_alpha=0.1, reg_lambda=0.1, subsample=0.8,
                          colsample_bytree=0.8, verbosity=0, early_stopping_rounds=50, random_state=RANDOM_STATE)

xgb_model1.fit(X_train_flat, y_train,
              eval_set=[(X_cv_flat, y_cv)],
              verbose=True)

# Step 5: Evaluate the Model
train_accuracy = accuracy_score(y_train, xgb_model1.predict(X_train_flat))
cv_accuracy = accuracy_score(y_cv, xgb_model1.predict(X_cv_flat))
test_accuracy = accuracy_score(y_test, xgb_model1.predict(X_test_flat))

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Validation Accuracy: {cv_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# [0]	validation_0-logloss:0.64911
# [1]	validation_0-logloss:0.61318
# [2]	validation_0-logloss:0.58198
# [3]	validation_0-logloss:0.55538
# [4]	validation_0-logloss:0.53375
# [5]	validation_0-logloss:0.51243
# [6]	validation_0-logloss:0.49192
# [7]	validation_0-logloss:0.47088
# [8]	validation_0-logloss:0.45693
# [9]	validation_0-logloss:0.44420
# [10]	validation_0-logloss:0.43324
# [11]	validation_0-logloss:0.42131
# [12]	validation_0-logloss:0.40694
# [13]	validation_0-logloss:0.39935
# [14]	validation_0-logloss:0.38916
# [15]	validation_0-logloss:0.37800
# [16]	validation_0-logloss:0.37077
# [17]	validation_0-logloss:0.36047
# [18]	validation_0-logloss:0.35156
# [19]	validation_0-logloss:0.34403
# [20]	validation_0-logloss:0.33915
# [21]	validation_0-logloss:0.33305
# [22]	validation_0-logloss:0.32865
# [23]	validation_0-logloss:0.32236
# [24]	validation_0-logloss:0.31945
# [25]	validation_0-logloss:0.31296
# [26]	validation_0-logloss:0.30696
# [27]	validation_0-logloss:0.29958
# ...

# %%
import joblib

# Save the model to a file
joblib.dump(xgb_model1, 'task1_2D_xgb_model500.pkl')
# Out:
# ['task1_2D_xgb_model500.pkl']

# %%
# Step 1: Load the saved model
xgb_model1 = joblib.load('task1_2D_xgb_model500.pkl')


# Step 3: Evaluate the loaded model
train_accuracy = accuracy_score(y_train, xgb_model1.predict(X_train_flat))
cv_accuracy = accuracy_score(y_cv, xgb_model1.predict(X_cv_flat))
test_accuracy = accuracy_score(y_test, xgb_model1.predict(X_test_flat))

# Step 4: Print the accuracy for each dataset
print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Validation Accuracy: {cv_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Training Accuracy: 1.0000
# Validation Accuracy: 0.9629
# Test Accuracy: 0.9622

# %%
# XGBoost Model Evaluation on Train and Test Data
print("\nXGBOOST Evaluation\n")

# Classification Report on Test Data
print("Classification Report (Test):")
print(classification_report(y_test, xgb_model1.predict(X_test_flat)))

# Confusion Matrix on Test Data
print("Confusion Matrix (Test):")
conf_test = confusion_matrix(y_test, xgb_model1.predict(X_test_flat))
print(conf_test)

# Accuracy Scores
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(xgb_model1.predict(X_train_flat), y_train):.4f}")
print(f"Metrics test:\n\tAccuracy score: {accuracy_score(xgb_model1.predict(X_test_flat), y_test):.4f}")


# Visualization for the Test Confusion Matrix
plt.figure(figsize=(10, 7.5))
sns.heatmap(conf_test, annot=True, cmap='BrBG', fmt='g')
plt.title("Confusion Matrix - Test Set")
plt.show()
# Out:
# XGBOOST Evaluation
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.99      0.94       405
#          1.0       0.99      0.95      0.97      1051
#
#     accuracy                           0.96      1456
#    macro avg       0.94      0.97      0.95      1456
# weighted avg       0.97      0.96      0.96      1456
#
# Confusion Matrix (Test):
# [[ 399    6]
#  [  49 1002]]
# Metrics train:
# 	Accuracy score: 1.0000
# Metrics test:
# 	Accuracy score: 0.9622
